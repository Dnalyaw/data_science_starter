# %% [markdown]
# # Chapter 3 - Regressoin Models
# ## Segment 1 - Simple linear regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

from pylab import rcParams

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import scale

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 10,8

# %%
rooms = 2*np.random.rand(100, 1)+3
rooms[1:10]
# Out:
# array([[3.03574239],
#        [3.00552583],
#        [4.81097195],
#        [3.90068131],
#        [3.12956141],
#        [4.63128502],
#        [4.22809987],
#        [3.19988906],
#        [3.73522238]])

# %%
price = 265 + 6*rooms +abs(np.random.randn(100, 1))
price[1:10]
# Out:
# array([[283.67702314],
#        [283.60797179],
#        [294.37407572],
#        [289.69411638],
#        [283.87473849],
#        [292.88778646],
#        [290.76469034],
#        [285.04684994],
#        [289.50912594]])

# %%
plt.plot(rooms, price, 'r^')
plt.xlabel("# of Rooms, 2019 Average")
plt.ylabel("2019 Average Home, 1000s USD")
plt.show()

# %%
X = rooms
y = price

LinReg = LinearRegression()
LinReg.fit(X,y)
print(LinReg.intercept_, LinReg.coef_)
# Out:
# [265.81543933] [[5.97586672]]

# %%
plt.plot(rooms, price, 'r^')
plt.xlabel("# of Rooms, 2019 Average")
plt.ylabel("2019 Average Home, 1000s USD")
x = np.linspace(3, 5, 8)
plt.plot(x, LinReg.coef_[0]*x+LinReg.intercept_[0])
plt.show()

# %% [markdown]
# *Simple Algebra*
# - y = mx + b
# - b = intercept = 265.7
#
# *Estimated Coefficients*
# - LinReg.coef_ = [5.99] Estimated coefficients for the terms in the linear regression problem.

# %%
print(LinReg.score(X,y))#r^2, showing what percentage of the house's price is actually calculated based on the # of rooms
# Out:
# 0.9743934004276312
