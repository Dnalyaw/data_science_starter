# %%
# !pip install quandl #import pip package

# %%
pip list #now on the list
# Out:
# Package                       Version
# ----------------------------- ---------------
# aiobotocore                   2.5.0
# aiofiles                      22.1.0
# aiohttp                       3.8.5
# aioitertools                  0.7.1
# aiosignal                     1.2.0
# aiosqlite                     0.18.0
# alabaster                     0.7.12
# anaconda-anon-usage           0.4.2
# anaconda-catalogs             0.2.0
# anaconda-client               1.12.1
# anaconda-cloud-auth           0.1.3
# anaconda-navigator            2.5.1
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# async-timeout                 4.0.2
# atomicwrites                  1.4.0
# ...

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- ---------------
# aiobotocore                   2.5.0
# aiofiles                      22.1.0
# aiohttp                       3.8.5
# aioitertools                  0.7.1
# aiosignal                     1.2.0
# aiosqlite                     0.18.0
# alabaster                     0.7.12
# anaconda-anon-usage           0.4.2
# anaconda-catalogs             0.2.0
# anaconda-client               1.12.1
# anaconda-cloud-auth           0.1.3
# anaconda-navigator            2.5.1
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# async-timeout                 4.0.2
# atomicwrites                  1.4.0
# ...

# %%
import pandas as pd
import quandl

# %%
apiKey = "im_92jJsC98R64Xnzuya"

# %%
df = quandl.get('WIKI/GOOGL', api_key=apiKey)#"GOOGL" could be changed to any ticker, apikey is so there are infinite requests

# %%
df #adjusted prices means with stock splits
# Out:
#                Open     High      Low     Close      Volume  Ex-Dividend  \
# Date
# 2004-08-19   100.01   104.06    95.96   100.335  44659000.0          0.0
# 2004-08-20   101.01   109.08   100.50   108.310  22834300.0          0.0
# 2004-08-23   110.76   113.48   109.05   109.400  18256100.0          0.0
# 2004-08-24   111.24   111.60   103.57   104.870  15247300.0          0.0
# 2004-08-25   104.76   108.00   103.88   106.000   9188600.0          0.0
# ...             ...      ...      ...       ...         ...          ...
# 2018-03-21  1092.57  1108.70  1087.21  1094.000   1990515.0          0.0
# 2018-03-22  1080.01  1083.92  1049.64  1053.150   3418154.0          0.0
# 2018-03-23  1051.37  1066.78  1024.87  1026.550   2413517.0          0.0
# 2018-03-26  1050.60  1059.27  1010.58  1054.090   3272409.0          0.0
# 2018-03-27  1063.90  1064.54   997.62  1006.940   2940957.0          0.0
#
#             Split Ratio    Adj. Open    Adj. High     Adj. Low   Adj. Close  \
# Date
# ...

# %%
df["Adj. Close"].plot()#so it works
# Out:
# <Axes: xlabel='Date'>

# %%
df2 = df[['Adj. Open', 'Adj. High', "Adj. Low", "Adj. Close", "Adj. Volume"]]#opening ticker $, high, low, closing ticker $

# %%
df2
# Out:
#               Adj. Open    Adj. High     Adj. Low   Adj. Close  Adj. Volume
# Date
# 2004-08-19    50.159839    52.191109    48.128568    50.322842   44659000.0
# 2004-08-20    50.661387    54.708881    50.405597    54.322689   22834300.0
# 2004-08-23    55.551482    56.915693    54.693835    54.869377   18256100.0
# 2004-08-24    55.792225    55.972783    51.945350    52.597363   15247300.0
# 2004-08-25    52.542193    54.167209    52.100830    53.164113    9188600.0
# ...                 ...          ...          ...          ...          ...
# 2018-03-21  1092.570000  1108.700000  1087.210000  1094.000000    1990515.0
# 2018-03-22  1080.010000  1083.920000  1049.640000  1053.150000    3418154.0
# 2018-03-23  1051.370000  1066.780000  1024.870000  1026.550000    2413517.0
# 2018-03-26  1050.600000  1059.270000  1010.580000  1054.090000    3272409.0
# 2018-03-27  1063.900000  1064.540000   997.620000  1006.940000    2940957.0
#
# [3424 rows x 5 columns]

# %%
df2['HL_PCT'] = (df['Adj. High'] - df['Adj. Low']) / df['Adj. Close'] * 100.0
df2['PCT_change'] = (df['Adj. Close'] - df['Adj. Open']) / df['Adj. Open'] * 100.0
df2
# Out:
# C:\Users\wayla\AppData\Local\Temp\ipykernel_8480\1665010458.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['HL_PCT'] = (df['Adj. High'] - df['Adj. Low']) / df['Adj. Close'] * 100.0
# C:\Users\wayla\AppData\Local\Temp\ipykernel_8480\1665010458.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['PCT_change'] = (df['Adj. Close'] - df['Adj. Open']) / df['Adj. Open'] * 100.0
#               Adj. Open    Adj. High     Adj. Low   Adj. Close  Adj. Volume  \
# Date
# ...

# %%
df3 = df2.copy()[['Adj. Close', 'HL_PCT', 'PCT_change','Adj. Volume']]
df3
# Out:
#              Adj. Close    HL_PCT  PCT_change  Adj. Volume
# Date
# 2004-08-19    50.322842  8.072956    0.324968   44659000.0
# 2004-08-20    54.322689  7.921706    7.227007   22834300.0
# 2004-08-23    54.869377  4.049360   -1.227880   18256100.0
# 2004-08-24    52.597363  7.657099   -5.726357   15247300.0
# 2004-08-25    53.164113  3.886792    1.183658    9188600.0
# ...                 ...       ...         ...          ...
# 2018-03-21  1094.000000  1.964351    0.130884    1990515.0
# 2018-03-22  1053.150000  3.254997   -2.487014    3418154.0
# 2018-03-23  1026.550000  4.082607   -2.360729    2413517.0
# 2018-03-26  1054.090000  4.619150    0.332191    3272409.0
# 2018-03-27  1006.940000  6.645878   -5.353887    2940957.0
#
# [3424 rows x 4 columns]

# %%
df3.isna().count()
# Out:
# Adj. Close     3424
# HL_PCT         3424
# PCT_change     3424
# Adj. Volume    3424
# dtype: int64

# %%
df4 = df3.fillna(-99999, inplace=True)

# %%
df3[df3.isna().any(axis=1)]#no nas in this dataframe
# Out:
# Empty DataFrame
# Columns: [Adj. Close, HL_PCT, PCT_change, Adj. Volume]
# Index: []

# %%
forecast_out = int(math.ceil(0.01*len(df)))#since the length is amount of days, this should cast out the next 0.1*all_days days
forecast_out
# Out:
# 35

# %%
forecast_col = 'Adj. Close'#what we will be predicting
df3['label'] = df3[forecast_col].shift(-forecast_out)#now shifted all values up because these final days were what we need to predict compared to the real days
df3
# Out:
#              Adj. Close    HL_PCT  PCT_change  Adj. Volume      label
# Date
# 2004-08-19    50.322842  8.072956    0.324968   44659000.0  69.078238
# 2004-08-20    54.322689  7.921706    7.227007   22834300.0  67.839414
# 2004-08-23    54.869377  4.049360   -1.227880   18256100.0  68.912727
# 2004-08-24    52.597363  7.657099   -5.726357   15247300.0  70.668146
# 2004-08-25    53.164113  3.886792    1.183658    9188600.0  71.219849
# ...                 ...       ...         ...          ...        ...
# 2018-03-21  1094.000000  1.964351    0.130884    1990515.0        NaN
# 2018-03-22  1053.150000  3.254997   -2.487014    3418154.0        NaN
# 2018-03-23  1026.550000  4.082607   -2.360729    2413517.0        NaN
# 2018-03-26  1054.090000  4.619150    0.332191    3272409.0        NaN
# 2018-03-27  1006.940000  6.645878   -5.353887    2940957.0        NaN
#
# [3424 rows x 5 columns]

# %%
df3.dropna(inplace=True)
df3
# Out:
#              Adj. Close    HL_PCT  PCT_change  Adj. Volume        label
# Date
# 2004-08-19    50.322842  8.072956    0.324968   44659000.0    69.078238
# 2004-08-20    54.322689  7.921706    7.227007   22834300.0    67.839414
# 2004-08-23    54.869377  4.049360   -1.227880   18256100.0    68.912727
# 2004-08-24    52.597363  7.657099   -5.726357   15247300.0    70.668146
# 2004-08-25    53.164113  3.886792    1.183658    9188600.0    71.219849
# ...                 ...       ...         ...          ...          ...
# 2018-01-30  1177.370000  1.139829   -0.029718    1792602.0  1094.000000
# 2018-01-31  1182.220000  1.202822   -0.134312    1643877.0  1053.150000
# 2018-02-01  1181.590000  1.530988    0.476195    2774967.0  1026.550000
# 2018-02-02  1119.200000  1.798606   -0.729098    5798880.0  1054.090000
# 2018-02-05  1068.760000  5.450241   -2.893850    3742469.0  1006.940000
#
# [3389 rows x 5 columns]

# %%
len(df3[df3.isna().any(axis=1)])#35 nans, perfect because it is a tenth of the rows and rounded up
# Out:
# 0

# %%
# !pip install scikit-learn

# %%
import numpy as np
from sklearn import preprocessing, model_selection, svm
from sklearn.linear_model import LinearRegression

# %%
X = np.array(df3.drop(['label'], axis=1))
X
# Out:
# array([[ 5.03228418e+01,  8.07295560e+00,  3.24967503e-01,
#          4.46590000e+07,             nan],
#        [ 5.43226889e+01,  7.92170621e+00,  7.22700723e+00,
#          2.28343000e+07,             nan],
#        [ 5.48693765e+01,  4.04936015e+00, -1.22788010e+00,
#          1.82561000e+07,             nan],
#        ...,
#        [ 1.18159000e+03,  1.53098791e+00,  4.76194525e-01,
#          2.77496700e+06,             nan],
#        [ 1.11920000e+03,  1.79860615e+00, -7.29098295e-01,
#          5.79888000e+06,             nan],
#        [ 1.06876000e+03,  5.45024140e+00, -2.89384977e+00,
#          3.74246900e+06,             nan]])

# %%
y = np.array(df3["label"])
y
# Out:
# array([  69.0782379 ,   67.83941377,   68.91272699, ..., 1026.55      ,
#        1054.09      , 1006.94      ])

# %%
X = preprocessing.scale(X) #creates a more normal distribution, no outliers or askew values to mess up data
X
# Out:
# C:\Users\wayla\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:232: RuntimeWarning: Mean of empty slice
#   mean_ = np.nanmean(X, axis)
# C:\Users\wayla\anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\wayla\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:240: RuntimeWarning: Mean of empty slice
#   mean_1 = np.nanmean(Xr, axis=0)
# C:\Users\wayla\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:247: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# C:\Users\wayla\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:259: RuntimeWarning: Mean of empty slice
#   mean_2 = np.nanmean(Xr, axis=0)
# ...

# %%
len(X), len(y)#X will predict the future and y will see the accuracy with the past with current data later
# Out:
# (3389, 3389)

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.2)

# %%
clf = LinearRegression()#running linearly
clf.fit(X_train, y_train)
accuracy = clf.score(X_test, y_test)

accuracy #pretty good accuracy
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[121], line 2
#       1 clf = LinearRegression()#running linearly
# ----> 2 clf.fit(X_train, y_train)
#       3 accuracy = clf.score(X_test, y_test)
#       5 accuracy
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:678, in LinearRegression.fit(self, X, y, sample_weight)
#     674 n_jobs_ = self.n_jobs
#     676 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# ...

# %%
forecast_out #should predict the next 35 days
# Out:
# 35

# %%
X = np.array(df3.drop(['label'], axis=1))
X = preprocessing.scale(X)
X_lately = X[-forecast_out:]
X = X[:-forecast_out:]
# Out:
# C:\Users\wayla\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:232: RuntimeWarning: Mean of empty slice
#   mean_ = np.nanmean(X, axis)
# C:\Users\wayla\anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\wayla\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:240: RuntimeWarning: Mean of empty slice
#   mean_1 = np.nanmean(Xr, axis=0)
# C:\Users\wayla\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:247: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# C:\Users\wayla\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:259: RuntimeWarning: Mean of empty slice
#   mean_2 = np.nanmean(Xr, axis=0)
# ...

# %%
forecast_set = clf.predict(X_lately)
forecast_set, accuracy, forecast_out
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 forecast_set = clf.predict(X_lately)
#       2 forecast_set, accuracy, forecast_out
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:386, in LinearModel.predict(self, X)
#     372 def predict(self, X):
#     373     """
#     374     Predict using the linear model.
#     375
#    (...)
#     384         Returns predicted values.
#     385     """
# --> 386     return self._decision_function(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:367, in LinearModel._decision_function(self, X)
#     366 def _decision_function(self, X):
# --> 367     check_is_fitted(self)
#     369     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     370     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# ...

# %%
import matplotlib.pyplot as plt
df3['Forecast'] = np.nan
df3
# Out:
#              Adj. Close    HL_PCT  PCT_change  Adj. Volume        label  \
# Date
# 2004-08-19    50.322842  8.072956    0.324968   44659000.0    69.078238
# 2004-08-20    54.322689  7.921706    7.227007   22834300.0    67.839414
# 2004-08-23    54.869377  4.049360   -1.227880   18256100.0    68.912727
# 2004-08-24    52.597363  7.657099   -5.726357   15247300.0    70.668146
# 2004-08-25    53.164113  3.886792    1.183658    9188600.0    71.219849
# ...                 ...       ...         ...          ...          ...
# 2018-01-30  1177.370000  1.139829   -0.029718    1792602.0  1094.000000
# 2018-01-31  1182.220000  1.202822   -0.134312    1643877.0  1053.150000
# 2018-02-01  1181.590000  1.530988    0.476195    2774967.0  1026.550000
# 2018-02-02  1119.200000  1.798606   -0.729098    5798880.0  1054.090000
# 2018-02-05  1068.760000  5.450241   -2.893850    3742469.0  1006.940000
#
#             Forecast
# Date
# 2004-08-19       NaN
# 2004-08-20       NaN
# 2004-08-23       NaN
# ...

# %%
import datetime
last_date = df3.iloc[-1].name
last_unix = last_date.timestamp()
one_day = 86400
next_unix = last_unix + one_day

for i in forecast_set:
    next_date = datetime.datetime.fromtimestamp(next_unix)
    next_unix += one_day
    df3.loc[next_date] = [np.nan for _ in range(len(df.columns)-1)] + [i]

    df3['Adj. Close'].plot()
    df3['Forecast'].plot()
    plt.legend(loc=4)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[114], line 10
#       8 next_date = datetime.datetime.fromtimestamp(next_unix)
#       9 next_unix += one_day
# ---> 10 df3.loc[next_date] = [np.nan for _ in range(len(df.columns)-1)] + [i]
#      12 df3['Adj. Close'].plot()
#      13 df3['Forecast'].plot()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:849, in _LocationIndexer.__setitem__(self, key, value)
#     846 self._has_valid_setitem_indexer(key)
#     848 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 849 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1825, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1822     indexer, missing = convert_missing_indexer(indexer)
#    1824     if missing:
# ...
