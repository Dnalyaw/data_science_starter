# %% [markdown]
# # Chapter 5 - Outlier Analysis
# ## Segment 9 - Multivariate analysis for outlier detection

# %%
import pandas as pd

import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sb

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5, 4
sb.set_style('whitegrid')

# %% [markdown]
# ### Visually inspecting boxplots

# %%
df = pd.read_csv(filepath_or_buffer="C:/Users/wayla/Python Data Analysis Exercise Files/Ex_Files_Python_Data_Science_EssT_Pt_1/Exercise Files/Data/iris.data.csv", header=None, sep=',')

df.columns=['Sepal Length','Sepal Width','Petal Length','Petal Width', 'Species']

# %%
df.groupby("Species").mean()["Sepal Length"] #mathes with box plot
# Out:
# Species
# setosa        5.006
# versicolor    5.936
# virginica     6.588
# Name: Sepal Length, dtype: float64

# %%
data = df.iloc[:,0:4].values
target = df.iloc[:,4].values

print(df[:5])

sb.boxplot(x='Species', y='Sepal Length', data=df, palette='hls')
#notice the outlier
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# <Axes: xlabel='Species', ylabel='Sepal Length'>

# %% [markdown]
# ### Looking at the scatterplot matrix

# %%
sb.pairplot(df, hue='Species', palette='hls')
# Out:
# C:\Users\wayla\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
