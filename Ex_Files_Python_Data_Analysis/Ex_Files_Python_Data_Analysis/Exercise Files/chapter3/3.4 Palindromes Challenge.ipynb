# %%
words = sorted({line.strip().lower() for line in open('words.txt', 'r')})

def reversed_word(word):
    #return ''.join(list(reversed([*word])))
    return word[::-1]

# %%
import collections

# %%
"hello".strip()
# Out:
# 'hello'

# %%
"hello".split()
# Out:
# ['hello']

# %%
(*"hello")
# Out:
#   Cell In[7], line 1
#     (*"hello")
#      ^
# SyntaxError: cannot use starred expression here

# %%
[*"hello"]
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
reversed_word = [*"hello"]

# %%
reversed_word
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
reversed_word.reverse()

# %%
reversed_word
# Out:
# ['o', 'l', 'l', 'e', 'h']

# %%
reversed("hello")

# %%
''.join(list(reversed([*"hello"])))
# Out:
# 'olleh'

# %%
''.join(list(reversed([*"hello"])))
# Out:
# 'olleh'

# %%
reversed_word("hello")
# Out:
# 'olleh'

# %%
words_by_sig = collections.defaultdict(set)

def find_palindrome(myword):
    if reversed_word(myword) in words:
        print(f"{myword} has a palindrome of {reversed_word(myword)}")

# %%
find_palindrome("drawer")
# Out:
# drawer has a palindrome of reward

# %%
for word in words:
    words_by_sig[word].add(reversed_word(word))

# %%
words_by_sig
# Out:
# defaultdict(set,
#             {'a': {'a'},
#              'aa': {'aa'},
#              'aal': {'laa'},
#              'aalii': {'iilaa'},
#              'aam': {'maa'},
#              'aani': {'inaa'},
#              'aardvark': {'kravdraa'},
#              'aardwolf': {'flowdraa'},
#              'aaron': {'noraa'},
#              'aaronic': {'cinoraa'},
#              'aaronical': {'lacinoraa'},
#              'aaronite': {'etinoraa'},
#              'aaronitic': {'citinoraa'},
#              'aaru': {'uraa'},
#              'ab': {'ba'},
#              'aba': {'aba'},
#              'ababdeh': {'hedbaba'},
#              'ababua': {'aubaba'},
#              'abac': {'caba'},
#              'abaca': {'acaba'},
#              'abacate': {'etacaba'},
#              'abacay': {'yacaba'},
#              'abacinate': {'etanicaba'},
#              'abacination': {'noitanicaba'},
#              'abaciscus': {'sucsicaba'},
#              'abacist': {'tsicaba'},
# ...

# %%
import math
import collections

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
words = sorted({line.strip().lower() for line in open('words.txt', 'r')})

def signature(word):
    return ''.join(sorted(word))

words_by_sig = collections.defaultdict(set)

for word in words:
    words_by_sig[signature(word)].add(word)

anagrams_by_sig = {sig: wordset for sig, wordset in words_by_sig.items() if len(wordset) > 1}

# %%
anagrams_by_sig
# Out:
# {'aal': {'aal', 'ala'},
#  'aam': {'aam', 'ama'},
#  'aacinor': {'aaronic', 'nicarao', 'ocarina'},
#  'aaeinort': {'aaronite', 'aeration'},
#  'aaru': {'aaru', 'aura'},
#  'ab': {'ab', 'ba'},
#  'aab': {'aba', 'baa'},
#  'aabc': {'abac', 'caba'},
#  'aabcort': {'abactor', 'acrobat'},
#  'aabft': {'abaft', 'bafta'},
#  'aabelno': {'abalone', 'balonea'},
#  'aabdennor': {'abandoner', 'reabandon'},
#  'aabcin': {'abanic', 'bianca'},
#  'aabirs': {'abaris', 'arabis'},
#  'aabs': {'abas', 'saba'},
#  'aabers': {'abaser', 'abrase'},
#  'aabet': {'abate', 'ateba', 'batea', 'beata'},
#  'aabert': {'abater', 'artabe', 'eartab', 'trabea'},
#  'abb': {'abb', 'bab'},
#  'aabb': {'abba', 'baba'},
#  'abbey': {'abbey', 'bebay'},
#  'abby': {'abby', 'baby'},
#  'aabdt': {'abdat', 'batad'},
#  'abdeil': {'abdiel', 'baldie'},
#  'aaabdgiilmnnoov': {'abdominovaginal', 'vaginoabdominal'},
#  'aabcdeiilmnoosv': {'abdominovesical', 'vesicoabdominal'},
#  'abe': {'abe', 'bae', 'bea'},
# ...

# %%
pairs = []

for wordset in anagrams_by_sig.values():
    for word1 in wordset:
        for word2 in wordset:
            if word1[::-1] == word2:
                pairs.append((word1, word2))

# %%
pairs
# Out:
# [['ala', 'ala'],
#  ['ama', 'ama'],
#  ['ab', 'ba'],
#  ['ba', 'ab'],
#  ['aba', 'aba'],
#  ['abac', 'caba'],
#  ['caba', 'abac'],
#  ['saba', 'abas'],
#  ['abas', 'saba'],
#  ['bab', 'bab'],
#  ['abba', 'abba'],
#  ['yalb', 'blay'],
#  ['blay', 'yalb'],
#  ['absi', 'isba'],
#  ['isba', 'absi'],
#  ['abut', 'tuba'],
#  ['tuba', 'abut'],
#  ['acara', 'araca'],
#  ['araca', 'acara'],
#  ['acca', 'acca'],
#  ['dirca', 'acrid'],
#  ['acrid', 'dirca'],
#  ['ad', 'da'],
#  ['da', 'ad'],
#  ['adda', 'adda'],
#  ['adad', 'dada'],
#  ['dada', 'adad'],
#  ['adar', 'rada'],
#  ['rada', 'adar'],
#  ['dad', 'dad'],
#  ['duad', 'daud'],
#  ['daud', 'duad'],
#  ['adet', 'teda'],
#  ['teda', 'adet'],
#  ['naid', 'dian'],
#  ['dian', 'naid'],
#  ['namda', 'adman'],
#  ['adman', 'namda'],
#  ['ado', 'oda'],
#  ['oda', 'ado'],
#  ['yard', 'dray'],
#  ['dray', 'yard'],
#  ['yad', 'day'],
#  ['day', 'yad'],
#  ['ea', 'ae'],
#  ['ae', 'ea'],
#  ['rea', 'aer'],
#  ['are', 'era'],
#  ['era', 'are'],
# ...

# %%
import itertools
list(itertools.combinations({1, 2, 3}, 2)) #displays every two number combination of (1, 2, 3)
# Out:
# [(1, 2), (1, 3), (2, 3)]

# %%
pairs = []

for wordset in anagrams_by_sig.values():
    for word1, word2 in itertools.combinations(wordset, 2):
            if word1[::-1] == word2:
                pairs.append((word1, word2))

# %%
pairs
# Out:
# [('ab', 'ba'),
#  ('abac', 'caba'),
#  ('saba', 'abas'),
#  ('yalb', 'blay'),
#  ('absi', 'isba'),
#  ('abut', 'tuba'),
#  ('acara', 'araca'),
#  ('dirca', 'acrid'),
#  ('ad', 'da'),
#  ('adad', 'dada'),
#  ('adar', 'rada'),
#  ('duad', 'daud'),
#  ('adet', 'teda'),
#  ('naid', 'dian'),
#  ('namda', 'adman'),
#  ('ado', 'oda'),
#  ('yard', 'dray'),
#  ('yad', 'day'),
#  ('ea', 'ae'),
#  ('rea', 'aer'),
#  ('are', 'era'),
#  ('aes', 'sea'),
#  ('agla', 'alga'),
#  ('agama', 'amaga'),
#  ('agar', 'raga'),
#  ('regga', 'agger'),
#  ('biga', 'agib'),
#  ('agrom', 'morga'),
#  ('agust', 'tsuga'),
#  ('ah', 'ha'),
#  ('ahom', 'moha'),
#  ('aht', 'tha'),
#  ('aider', 'redia'),
#  ('aile', 'elia'),
#  ('ami', 'ima'),
#  ('ria', 'air'),
#  ('aira', 'aria'),
#  ('aire', 'eria'),
#  ('ati', 'ita'),
#  ('raja', 'ajar'),
#  ('ak', 'ka'),
#  ('oka', 'ako'),
#  ('kua', 'auk'),
#  ('al', 'la'),
#  ('lana', 'anal'),
#  ('lab', 'bal'),
#  ('laban', 'nabal'),
#  ('nabla', 'alban'),
# ...
